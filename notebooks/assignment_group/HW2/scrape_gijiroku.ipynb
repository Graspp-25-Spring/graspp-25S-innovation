# %%
#!/usr/bin/env python3
# -*- coding: utf-8 -*-

import time
import pandas as pd
import numpy as np

from selenium import webdriver
from selenium.webdriver.chrome.options import Options
from webdriver_manager.chrome import ChromeDriverManager

def fetch_yonalog_counts(url: str, wait_seconds: float = 5.0):
    # 1) Configure headless Chrome
    chrome_opts = Options()
    chrome_opts.add_argument("--headless")
    chrome_opts.add_argument("--disable-gpu")
    chrome_opts.add_argument("--no-sandbox")
    chrome_opts.add_argument("--window-size=1920,1080")
    
    # 2) Launch driver (auto-downloads chromedriver)
    driver = webdriver.Chrome(
        options=chrome_opts
    )
    
    try:
        # 3) Navigate
        driver.get(url)
        
        # 4) Wait for JS to render the chart
        time.sleep(wait_seconds)
        
        # 5) Extract the live chart options
        #    Highcharts.charts[0] is the first (and only) chart on the page
        cfg = driver.execute_script("return Highcharts.charts[0].options;")
        
    finally:
        driver.quit()
    
    return cfg

# %%
# current text: "鉱業"+%7C+"採石業"+%7C+"砂利採取業"
URL = "https://chiholog.net/yonalog/search.html?meeting_text=%22%E9%89%B1%E6%A5%AD%22+%7C+%22%E6%8E%A1%E7%9F%B3%E6%A5%AD%22+%7C+%22%E7%A0%82%E5%88%A9%E6%8E%A1%E5%8F%96%E6%A5%AD%22#google_vignette"

def build_yonalog_url(queries):
    # URL encode each query and join with ' | '
    encoded_queries = [q if q.startswith('"') else f'"{q}"' for q in queries]
    joined = ' | '.join(encoded_queries)
    encoded = urllib.parse.quote(joined)
    base_url = "https://chiholog.net/yonalog/search.html?meeting_text="
    return f"{base_url}{encoded}"

# %%
def get_district_timeseries(cfg: dict, district_name: str):
    """
    Given the Highcharts options dict and a district name (e.g. "全議会" or "福岡県議会"),
    return an ordered dict mapping year → count for that single series.
    """
    # 1947 ~ 2024
    years = list(range(1947, 2025))
    for series in cfg["series"]:
        if district_name in series["name"]:
            counts = np.array(series["data"])[:, 1].astype(int)
            # Ensure both years and counts are Python ints
            return {int(year): int(count) for year, count in zip(years, counts)}
    raise ValueError(f"Series named '{district_name}' not found in chart")

# %%
def get_industry_mention_counts(industry_name: list[str]):
    """
    Given the Highcharts options dict and an industry name (e.g. ["鉱業", "採石業", "砂利採取業"]),
    return a pandas dataframe with year as index and counts as a single column.
    The dataframe will have years from 1947 to 2024.
    """
    # 1947 ~ 2024
    cfg = fetch_yonalog_counts(build_yonalog_url(industry_name))
    dic = get_district_timeseries(cfg, "全議会")
    df = pd.DataFrame.from_dict(dic, orient='index', columns=['count'])
    return df

# %%
import tqdm
from industries import id2industries_dict

def refine_industry_name(industry: str) -> list[str]:
    industry = industry.replace("紙、", "")
    pulp_flag = False
    industry = industry.replace("，", "、").replace(",", "、")
    if "公園、" in industry:
        industry = industry.replace("公園、", "")
    if "同" in industry:
        industry = industry.replace("同", industry.split("・")[0])
    if "パルプ" in industry:
        pulp_flag = True
    if "（" in industry:
        industry = industry.split("（")[0]
    if "(" in industry:
        industry = industry.split("(")[0]
    industry = industry.strip()
    if "・" in industry:
        industry = industry.split("・")
        return [ind + "業" if not ind.endswith("業") else ind for ind in industry]
    if "、" in industry:
        if pulp_flag:
            return ["パルプ紙"] + industry.split("、")
        else:
            return industry.split("、")
    if pulp_flag:
        return ["パルプ紙"] + [industry] if industry else []
    return [industry] if industry else []

indic = id2industries_dict
indic2 = {k: refine_industry_name(v) for k, v in indic.items()}

# %%
for k, v in tqdm.tqdm(indic2.items()):
    print(f"Processing {k} -> {v}")
# Out:
# 100%|██████████| 158/158 [00:00<00:00, 53983.38it/s]
# Processing 000 -> ['合計']
# Processing C -> ['鉱業', '採石業', '砂利採取業']
# Processing E -> ['製造業']
# Processing 090 -> ['食料品製造業']
# Processing 091 -> ['畜産食料品製造業']
# Processing 092 -> ['水産食料品製造業']
# Processing 093 -> ['精穀業', '製粉業']
# Processing 099 -> ['その他の食料品製造業']
# Processing 100 -> ['飲料業', 'たばこ業', '飼料製造業']
# Processing 101 -> ['清涼飲料業', '酒類業', '茶業', 'たばこ製造業']
# Processing 102 -> ['飼料業', '有機質肥料製造業']
# Processing 110 -> ['繊維工業']
# Processing 111 -> ['製糸', '紡績', 'ねん糸等製造業']
# Processing 112 -> ['織物業', 'ニット生地製造業']
# Processing 113 -> ['染色整理業']
# Processing 114 -> ['その他の繊維工業']
# Processing 115 -> ['織物業', 'ニット製衣服製造業']
# Processing 119 -> ['身の回り品業', 'その他の繊維製品製造業']
# Processing 120 -> ['木材業', '木製品製造業']
# Processing 121 -> ['製材業', '合板製造業']
# Processing 129 -> ['その他の木製品製造業']
# Processing 130 -> ['家具業', '装備品製造業']
# Processing 140 -> ['パルプ業', '紙業', '紙加工品製造業']
# Processing 141 -> ['パルプ業', '紙製造業']
# Processing 142 -> ['紙加工品製造業']
# Processing 150 -> ['印刷業', '印刷関連業']
# Processing 160 -> ['化学工業']
# Processing 161 -> ['化学肥料業', '無機化学工業製品製造業']
# Processing 162 -> ['有機化学工業製品製造業']
# Processing 163 -> ['油脂加工製品業', '石けん業', '合成洗剤業', '界面活性剤業', '塗料製造業']
# Processing 164 -> ['医薬品製造業']
# Processing 169 -> ['その他の化学工業製品製造業']
# Processing 170 -> ['石油製品業', '石炭製品製造業']
# Processing 171 -> ['石油精製業']
# Processing 179 -> ['その他の石油製品業', '石炭製品製造業']
# Processing 180 -> ['プラスチック製品製造業']
# Processing 190 -> ['ゴム製品製造業']
# Processing 191 -> ['タイヤ業', 'チューブ製造業']
# Processing 199 -> ['その他のゴム製品製造業']
# Processing 200 -> ['なめし革業', 'なめし革製品業', '毛皮製造業']
# Processing 210 -> ['窯業', '土石製品製造業']
# Processing 211 -> ['ガラス業', 'ガラス製品製造業']
# Processing 212 -> ['セメント業', 'セメント製品製造業']
# Processing 219 -> ['その他の窯業', '土石製品製造業']
# Processing 220 -> ['鉄鋼業']
# Processing 221 -> ['銑鉄業', '粗鋼業', '鋼材製造業']
# Processing 222 -> ['鋳鍛造品業', 'その他の鉄鋼製品製造業']
# Processing 230 -> ['非鉄金属製造業']
# Processing 231 -> ['非鉄金属製錬業', '精製業']
# Processing 232 -> ['非鉄金属加工品製造業']
# Processing 240 -> ['金属製品製造業']
# Processing 241 -> ['建設用業', '建築用金属製品製造業']
# Processing 249 -> ['その他の金属製品製造業']
# Processing 250 -> ['はん用機械器具製造業']
# Processing 251 -> ['ボイラ業', '原動機製造業']
# Processing 252 -> ['ポンプ業', '圧縮機器製造業']
# Processing 253 -> ['一般産業用機械業', '装置製造業']
# Processing 259 -> ['その他のはん用機械業', 'その他のはん用機械部品製造業']
# Processing 260 -> ['生産用機械器具製造業']
# Processing 261 -> ['金属加工機械製造業']
# Processing 262 -> ['特殊産業用機械製造業']
# Processing 270 -> ['業務用機械器具製造業']
# Processing 271 -> ['事務用業', 'サービス用機械器具製造業']
# Processing 273 -> ['計量器業', '測定器業', '分析機器業', '試験機業', '測量機製造業']
# Processing 274 -> ['医療用機械器具業', '医療用品製造業']
# Processing 275 -> ['光学機械器具業', 'レンズ製造業']
# Processing 276 -> ['武器製造業']
# Processing 280 -> ['電子部品業', 'デバイス業', '電子回路製造業']
# Processing 290 -> ['電気機械器具製造業']
# Processing 291 -> ['産業用電気機械器具製造業']
# Processing 292 -> ['民生用電気機械器具製造業']
# Processing 293 -> ['電子応用装置製造業']
# Processing 299 -> ['その他の電気機械器具製造業']
# Processing 300 -> ['情報通信機械器具製造業']
# Processing 301 -> ['通信機械器具業', '通信機械器具関連機械器具製造業']
# Processing 302 -> ['電子計算機業', '電子計算機附属装置製造業']
# Processing 310 -> ['輸送用機械器具製造業']
# Processing 311 -> ['自動車業', '自動車附属品製造業']
# Processing 319 -> ['その他の輸送用機械器具製造業']
# Processing 320 -> ['その他の製造業']
# Processing F -> ['電気業', 'ガス業']
# Processing 331 -> ['電気業']
# Processing 341 -> ['ガス業']
# Processing G -> ['情報通信業']
# Processing 391 -> ['ソフトウェア業']
# Processing 392 -> ['情報処理業', '提供サービス業']
# Processing 401 -> ['インターネット附随サービス業']
# Processing 411 -> ['映画業', 'ビデオ制作業']
# Processing 413 -> ['新聞業']
# Processing 414 -> ['出版業']
# Processing I1 -> ['卸売業']
# Processing 511 -> ['繊維品卸売業']
# Processing 512 -> ['衣服業', '身の回り品卸売業']
# Processing 521 -> ['農畜産物業', '水産物卸売業']
# Processing 522 -> ['食料業', '飲料卸売業']
# Processing 531 -> ['建築材料卸売業']
# Processing 532 -> ['化学製品卸売業']
# Processing 533 -> ['石油業', '鉱物卸売業']
# Processing 534 -> ['鉄鋼製品卸売業']
# Processing 535 -> ['非鉄金属卸売業']
# Processing 536 -> ['再生資源卸売業']
# Processing 541 -> ['産業機械器具卸売業']
# Processing 542 -> ['自動車卸売業']
# Processing 543 -> ['電気機械器具卸売業']
# Processing 549 -> ['その他の機械器具卸売業']
# Processing 551 -> ['家具業', '建具業', 'じゅう器等卸売業']
# Processing 552 -> ['医薬品業', '化粧品等卸売業']
# Processing 553 -> ['紙製品卸売業']
# Processing 559 -> ['その他の卸売業']
# Processing I2 -> ['小売業']
# Processing 570 -> ['織物業', '衣服業', '身の回り品小売業']
# Processing 580 -> ['飲食料品小売業']
# Processing 591 -> ['自動車業', '自転車小売業']
# Processing 593 -> ['機械器具小売業']
# Processing 602 -> ['家具業', '建具業', 'じゅう器小売業']
# Processing 603 -> ['医薬品業', '化粧品小売業']
# Processing 605 -> ['燃料小売業']
# Processing 609 -> ['その他の小売業']
# Processing 610 -> ['無店舗小売業']
# Processing J1 -> ['クレジットカード業', '割賦金融業']
# Processing K1 -> ['物品賃貸業']
# Processing 702 -> ['産業用機械器具賃貸業']
# Processing 703 -> ['事務用機械器具賃貸業']
# Processing 704 -> ['自動車賃貸業']
# Processing 708 -> ['その他の物品賃貸業']
# Processing L -> ['学術研究、専門業', '技術サービス業']
# Processing 710 -> ['学術業', '開発研究機関業']
# Processing 726 -> ['デザイン業']
# Processing 728 -> ['エンジニアリング業']
# Processing 730 -> ['広告業']
# Processing 743 -> ['機械設計業']
# Processing 744 -> ['商品業', '非破壊検査業']
# Processing 745 -> ['計量証明業']
# Processing 746 -> ['写真業']
# Processing M -> ['飲食サービス業']
# Processing 760 -> ['一般飲食店']
# Processing 770 -> ['持ち帰り業', '配達飲食サービス業']
# Processing N -> ['生活関連サービス業', '娯楽業']
# Processing 781 -> ['洗濯業']
# Processing 789 -> ['その他の洗濯業', '理容業', '美容業', '浴場業']
# Processing 796 -> ['冠婚葬祭業']
# Processing 797 -> ['写真プリント、現像業', '焼付業']
# Processing 798 -> ['その他の生活関連サービス業']
# Processing 801 -> ['映画館']
# Processing 803 -> ['ゴルフ場']
# Processing 804 -> ['スポーツ施設提供業']
# Processing 805 -> ['遊園地業', 'テーマパーク業']
# Processing O -> ['個人教授所']
# Processing R1 -> ['サービス業']
# Processing 880 -> ['廃棄物処理業']
# Processing 900 -> ['機械等修理業']
# Processing 911 -> ['職業紹介業']
# Processing 912 -> ['労働者派遣業']
# Processing 927 -> ['ディスプレイ業']
# Processing 928 -> ['テレマーケティング業']
# Processing 929 -> ['その他の事業サービス業']
# Processing R2 -> ['サービス業']
# Processing Z -> ['その他の産業']

# %%
import os

checkpoint_path = "all_df_checkpoint.csv"

# Load checkpoint if exists
if os.path.exists(checkpoint_path):
    all_df = pd.read_csv(checkpoint_path, index_col=0)
else:
    all_df = pd.DataFrame()

for k, industry in tqdm.tqdm(indic2.items()):
    col_name = ''.join(indic[k])
    if industry == ['合計'] or col_name in all_df.columns:
        continue
    try:
        df = get_industry_mention_counts(industry)
        df.columns = [col_name]
        if all_df.empty:
            all_df = df
        else:
            all_df = all_df.join(df, how='outer')
        # Save checkpoint after each successful column
        all_df.to_csv(checkpoint_path)
    except Exception as e:
        print(f"Error processing {k} ({industry}): {e}")
# Out:
# 100%|██████████| 158/158 [03:09<00:00,  1.20s/it]

# %%
indic
reversed_indic = {v: k for k, v in indic.items()}

# %%
all_df.loc['industry_id'] = [reversed_indic[col] for col in all_df.columns]
all_df = all_df.loc[['industry_id'] + [idx for idx in all_df.index if idx != 'industry_id']]
all_df.to_csv("gikai_mention.csv")
